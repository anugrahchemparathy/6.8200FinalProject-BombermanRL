# %%
from pathlib import Path

import gym
import torch
import torch.nn as nn

from easyrl.agents.ppo_agent import PPOAgent
from easyrl.configs import cfg
from easyrl.configs import set_config
from easyrl.configs.command_line import cfg_from_cmd
from easyrl.engine.ppo_engine import PPOEngine
from easyrl.models.categorical_policy import CategoricalPolicy
from easyrl.models.diag_gaussian_policy import DiagGaussianPolicy
from easyrl.models.mlp import MLP
from easyrl.models.value_net import ValueNet
from easyrl.runner.nstep_runner import EpisodicRunner
from easyrl.utils.common import set_random_seed
from easyrl.utils.gym_util import make_vec_env

import new_env as bomberman_env
from models import ActorModel

def set_configs(exp_name='ppo_base'):
    set_config('ppo')
    cfg.alg.num_envs = 1
    cfg.alg.episode_steps = 150
    cfg.alg.max_steps = 600000
    cfg.alg.device = 'cuda' if torch.cuda.is_available() else 'cpu'
    cfg.alg.env_name = 'Bomberman-v1'
    cfg.alg.save_dir = Path.cwd().absolute().joinpath('data').as_posix()
    cfg.alg.save_dir += f'/{exp_name}'
    setattr(cfg.alg, 'diff_cfg', dict(save_dir=cfg.alg.save_dir))

    print(f'====================================')
    print(f'      Device:{cfg.alg.device}')
    print(f'====================================')

def main():
    set_configs()

    set_random_seed(cfg.alg.seed)
    env = make_vec_env(cfg.alg.env_name,
                       cfg.alg.num_envs,
                       seed=cfg.alg.seed)
    env.reset()
    ob_size = env.observation_space.shape[0]

    act_size = env.action_space.n
    actor_body = ActorModel(act_size)
    critic_body = ActorModel(act_size)

    actor = CategoricalPolicy(actor_body,
                                in_features=64,
                                action_dim=act_size)

    critic = ValueNet(critic_body, in_features=64)
    agent = PPOAgent(actor=actor, critic=critic, env=env)
    runner = EpisodicRunner(agent=agent, env=env)
    engine = PPOEngine(agent=agent,
                       runner=runner)
    if not cfg.alg.test:
        engine.train()
    else:
        stat_info, raw_traj_info = engine.eval(render=cfg.alg.render,
                                               save_eval_traj=cfg.alg.save_test_traj,
                                               eval_num=cfg.alg.test_num,
                                               sleep_time=0.04)
        import pprint
        pprint.pprint(stat_info)
    env.close()

# %%
main()
# Out:
# [INFO][2023-05-13 01:47:52]: Alogrithm type:<class 'easyrl.configs.ppo_config.PPOConfig'>
# [INFO][2023-05-13 01:47:52]: Creating 1 environments.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gym/utils/passive_env_checker.py:20: UserWarning: WARN: It seems a Box observation space is an image but the `dtype` is not `np.uint8`, actual type: int8. If the Box observation space is not an image, we recommend flattening the observation to have only a 1D vector.
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gym/utils/passive_env_checker.py:25: UserWarning: WARN: It seems a Box observation space is an image but the upper and lower bounds are not in [0, 255]. Generally, CNN policies assume observations are within that range, so you may encounter an issue if the observation values are not.
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gym/utils/passive_env_checker.py:174: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed a `seed` instead of using `Env.seed` for resetting the environment random number generator.
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gym/utils/passive_env_checker.py:187: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gym/utils/passive_env_checker.py:195: UserWarning: WARN: The result returned by `env.reset()` was not a tuple of the form `(obs, info)`, where `obs` is a observation and `info` is a dictionary containing additional information. Actual type: `<class 'numpy.ndarray'>`
#   logger.warn(
# [ERROR][2023-05-13 01:47:52]: Not a valid git repo: /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages
# /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/game_objects.py:42: RuntimeWarning: invalid value encountered in sqrt
#   bomb_distances = np.where(bomb_distances > 1, np.sqrt(bomb_distances-1), bomb_distances-1)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gym/utils/passive_env_checker.py:219: DeprecationWarning: WARN: Core environment is written in old step API which returns one bool instead of two. It is recommended to rewrite the environment with new step API.
#   logger.deprecation(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gym/utils/passive_env_checker.py:225: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(done, (bool, np.bool8)):
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gym/utils/passive_env_checker.py:141: UserWarning: WARN: The obs returned by the `step()` method was expecting numpy array dtype to be int8, actual type: int64
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/gym/utils/passive_env_checker.py:165: UserWarning: WARN: The obs returned by the `step()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# [INFO][2023-05-13 01:47:52]: Exploration steps: 0
# [INFO][2023-05-13 01:47:52]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/ckpt_000000000000.pt.
# [INFO][2023-05-13 01:47:52]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/model_best.pt.
# ====================================
#       Device:cpu
# ====================================
# [INFO][2023-05-13 01:48:52]: Exploration steps: 15000
# [INFO][2023-05-13 01:48:52]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/ckpt_000000015000.pt.
# [INFO][2023-05-13 01:49:53]: Exploration steps: 30000
# [INFO][2023-05-13 01:49:53]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/ckpt_000000030000.pt.
# [INFO][2023-05-13 01:50:51]: Exploration steps: 45000
# [INFO][2023-05-13 01:50:51]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/ckpt_000000045000.pt.
# [INFO][2023-05-13 01:51:50]: Exploration steps: 60000
# [INFO][2023-05-13 01:51:50]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/ckpt_000000060000.pt.
# [INFO][2023-05-13 01:52:48]: Exploration steps: 75000
# [INFO][2023-05-13 01:52:48]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/ckpt_000000075000.pt.
# [INFO][2023-05-13 01:53:47]: Exploration steps: 90000
# [INFO][2023-05-13 01:53:47]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/ckpt_000000090000.pt.
# [INFO][2023-05-13 01:54:46]: Exploration steps: 105000
# [INFO][2023-05-13 01:54:46]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/ckpt_000000105000.pt.
# [INFO][2023-05-13 01:54:46]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/model_best.pt.
# [INFO][2023-05-13 01:55:45]: Exploration steps: 120000
# [INFO][2023-05-13 01:55:45]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/ckpt_000000120000.pt.
# [INFO][2023-05-13 01:56:43]: Exploration steps: 135000
# [INFO][2023-05-13 01:56:43]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/ckpt_000000135000.pt.
# [INFO][2023-05-13 01:56:43]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/model_best.pt.
# [INFO][2023-05-13 01:57:42]: Exploration steps: 150000
# [INFO][2023-05-13 01:57:42]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/ckpt_000000150000.pt.
# [INFO][2023-05-13 01:58:40]: Exploration steps: 165000
# [INFO][2023-05-13 01:58:40]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/ckpt_000000165000.pt.
# [INFO][2023-05-13 01:58:40]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/model_best.pt.
# [INFO][2023-05-13 01:59:39]: Exploration steps: 180000
# [INFO][2023-05-13 01:59:39]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/ckpt_000000180000.pt.
# [INFO][2023-05-13 01:59:39]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/model_best.pt.
# [INFO][2023-05-13 02:00:38]: Exploration steps: 195000
# [INFO][2023-05-13 02:00:38]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/ckpt_000000195000.pt.
# [INFO][2023-05-13 02:01:37]: Exploration steps: 210000
# [INFO][2023-05-13 02:01:37]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/ckpt_000000210000.pt.
# [INFO][2023-05-13 02:01:37]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/model_best.pt.
# [INFO][2023-05-13 02:02:36]: Exploration steps: 225000
# [INFO][2023-05-13 02:02:36]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/ckpt_000000225000.pt.
# [INFO][2023-05-13 02:03:35]: Exploration steps: 240000
# [INFO][2023-05-13 02:03:35]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/ckpt_000000240000.pt.
# [INFO][2023-05-13 02:04:35]: Exploration steps: 255000
# [INFO][2023-05-13 02:04:35]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/ckpt_000000255000.pt.
# [INFO][2023-05-13 02:04:35]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/model_best.pt.
# [INFO][2023-05-13 02:05:37]: Exploration steps: 270000
# [INFO][2023-05-13 02:05:37]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/ckpt_000000270000.pt.
# [INFO][2023-05-13 02:06:40]: Exploration steps: 285000
# [INFO][2023-05-13 02:06:40]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/ckpt_000000285000.pt.
# [INFO][2023-05-13 02:07:41]: Exploration steps: 300000
# [INFO][2023-05-13 02:07:41]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/ckpt_000000300000.pt.
# [INFO][2023-05-13 02:08:44]: Exploration steps: 315000
# [INFO][2023-05-13 02:08:44]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/ckpt_000000315000.pt.
# [INFO][2023-05-13 02:09:46]: Exploration steps: 330000
# [INFO][2023-05-13 02:09:46]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/ckpt_000000330000.pt.
# [INFO][2023-05-13 02:10:46]: Exploration steps: 345000
# [INFO][2023-05-13 02:10:46]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/ckpt_000000345000.pt.
# [INFO][2023-05-13 02:11:46]: Exploration steps: 360000
# [INFO][2023-05-13 02:11:46]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/ckpt_000000360000.pt.
# [INFO][2023-05-13 02:12:47]: Exploration steps: 375000
# [INFO][2023-05-13 02:12:47]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/ckpt_000000375000.pt.
# [INFO][2023-05-13 02:12:47]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/model_best.pt.
# [INFO][2023-05-13 02:13:49]: Exploration steps: 390000
# [INFO][2023-05-13 02:13:49]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/ckpt_000000390000.pt.
# [INFO][2023-05-13 02:14:50]: Exploration steps: 405000
# [INFO][2023-05-13 02:14:50]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/ckpt_000000405000.pt.
# [INFO][2023-05-13 02:14:50]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/model_best.pt.
# [INFO][2023-05-13 02:15:51]: Exploration steps: 420000
# [INFO][2023-05-13 02:15:51]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/ckpt_000000420000.pt.
# [INFO][2023-05-13 02:16:52]: Exploration steps: 435000
# [INFO][2023-05-13 02:16:52]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/ckpt_000000435000.pt.
# [INFO][2023-05-13 02:17:51]: Exploration steps: 450000
# [INFO][2023-05-13 02:17:51]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/ckpt_000000450000.pt.
# [INFO][2023-05-13 02:18:51]: Exploration steps: 465000
# [INFO][2023-05-13 02:18:51]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/ckpt_000000465000.pt.
# [INFO][2023-05-13 02:19:50]: Exploration steps: 480000
# [INFO][2023-05-13 02:19:50]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/ckpt_000000480000.pt.
# [INFO][2023-05-13 02:20:49]: Exploration steps: 495000
# [INFO][2023-05-13 02:20:49]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/ckpt_000000495000.pt.
# [INFO][2023-05-13 02:21:48]: Exploration steps: 510000
# [INFO][2023-05-13 02:21:48]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/ckpt_000000510000.pt.
# [INFO][2023-05-13 02:22:47]: Exploration steps: 525000
# [INFO][2023-05-13 02:22:47]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/ckpt_000000525000.pt.
# [INFO][2023-05-13 02:23:46]: Exploration steps: 540000
# [INFO][2023-05-13 02:23:46]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/ckpt_000000540000.pt.
# [INFO][2023-05-13 02:24:45]: Exploration steps: 555000
# [INFO][2023-05-13 02:24:45]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/ckpt_000000555000.pt.
# [INFO][2023-05-13 02:25:43]: Exploration steps: 570000
# [INFO][2023-05-13 02:25:43]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/ckpt_000000570000.pt.
# [INFO][2023-05-13 02:26:42]: Exploration steps: 585000
# [INFO][2023-05-13 02:26:42]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/ckpt_000000585000.pt.
# [INFO][2023-05-13 02:27:41]: Exploration steps: 600000
# [INFO][2023-05-13 02:27:41]: Saving checkpoint: /Users/anugrahchemparathy/Documents/6.8200FinalProject-BombermanRL/env_tools/data/ppo_base/seed_0/model/ckpt_000000600000.pt.
